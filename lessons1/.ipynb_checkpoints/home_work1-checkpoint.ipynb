# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 10, 100)
k = 1
plt.plot(x, np.cos(k*x), color='blue')
k = 1.2
plt.plot(x, np.cos(k*x), color='yellow')
plt.xlabel('x')
plt.ylabel('y')
plt.axis('tight')
plt.show()
